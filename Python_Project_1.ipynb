# %%
df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df2=df['School Name']=['P.S. 034 Franklin D. Roosevelt']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e5cb3776cb42> in <cell line: 0>()
# ----> 1 df2=df['School Name']=['P.S. 034 Franklin D. Roosevelt']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# ...

# %%
df.groupby(['School Name'])

# %%
df.groupby(['School Name']).count()
# Out:
#                                                     School DBN  School Level  \
# School Name
# 47 The American Sign Language and English Secondar         356           356
# A. Philip Randolph Campus High School                      459           459
# ACORN Community High School                                364           364
# Abraham Lincoln High School                                480           480
# Abraham Lincoln Yabc                                       248           248
# ...                                                        ...           ...
# Young Women's Leadership School                            378           378
# Young Women's Leadership School of Brooklyn                337           337
# Young Women's Leadership School of the Bronx               142           142
# Young Women's Leadership School, Astoria                   338           338
# Young Women's Leadership School, Queens                    391           391
#
# ...

# %%
df2=df[df['School Name']=='P.S. 034 Franklin D. Roosevelt']

# %%
df2.head()
# Out:
#       School DBN                     School Name School Level  \
# 0         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 0      Common Core Algebra  2017             4          s
# 1       Living Environment  2015            16       77.9
# 2       Living Environment  2016             9         74
# 19478  Common Core Algebra  2017             3          s
# 19479  Common Core Algebra  2017             1          s
#
#       Number Scoring Below 65 Percent Scoring Below 65  \
# 0                           s                        s
# 1                           1                      6.3
# 2                           1                     11.1
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df2.describe()
# Out:
#               Year  Total Tested
# count    29.000000     29.000000
# mean   2015.931034      5.000000
# std       0.842235      4.191829
# min    2015.000000      1.000000
# 25%    2015.000000      2.000000
# 50%    2016.000000      3.000000
# 75%    2017.000000      7.000000
# max    2017.000000     16.000000

# %%
df2.count()
# Out:
# School DBN                     29
# School Name                    29
# School Level                   29
# Regents Exam                   29
# Year                           29
# Total Tested                   29
# Mean Score                     29
# Number Scoring Below 65        29
# Percent Scoring Below 65       29
# Number Scoring 65 or Above     29
# Percent Scoring 65 or Above    29
# Number Scoring 80 or Above     29
# Percent Scoring 80 or Above    29
# Number Scoring CR              29
# Percent Scoring CR             29
# dtype: int64

# %%
df2.hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Total Tested'}>]], dtype=object)

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
 df.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-759307761548> in <cell line: 0>()
# ----> 1 df.summary()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'summary'

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df2=df[df["School Name"]]=="P.S. 034 Franklin D. Roosevelt"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9c747cf6fe64> in <cell line: 0>()
# ----> 1 df2=df[df["School Name"]]=="P.S. 034 Franklin D. Roosevelt"
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %% [markdown]
# df2=df[df["School Name"]]=="P.S. 034 Franklin D. Roosevelt"

# %%
df2=df[df["School Name"]=="P.S. 034 Franklin D. Roosevelt"]

# %%
df2.head()
# Out:
#       School DBN                     School Name School Level  \
# 0         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 0      Common Core Algebra  2017             4          s
# 1       Living Environment  2015            16       77.9
# 2       Living Environment  2016             9         74
# 19478  Common Core Algebra  2017             3          s
# 19479  Common Core Algebra  2017             1          s
#
#       Number Scoring Below 65 Percent Scoring Below 65  \
# 0                           s                        s
# 1                           1                      6.3
# 2                           1                     11.1
# ...

# %%
df2.describe()
# Out:
#               Year  Total Tested
# count    29.000000     29.000000
# mean   2015.931034      5.000000
# std       0.842235      4.191829
# min    2015.000000      1.000000
# 25%    2015.000000      2.000000
# 50%    2016.000000      3.000000
# 75%    2017.000000      7.000000
# max    2017.000000     16.000000

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
df2.tail()
# Out:
#        School DBN                     School Name School Level  \
# 139888     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139889     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139890     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139891     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139892     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 139888  Living Environment  2015             6       75.5
# 139889  Living Environment  2015             1          s
# 139890  Living Environment  2016             1          s
# 139891  Living Environment  2016             2          s
# 139892  Living Environment  2016             6       73.5
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 139888                       1                     16.7
# 139889                       s                        s
# 139890                       s                        s
# ...

# %%
print (df2)
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54234      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54235      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54236      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54238      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54239      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54240      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# ...

# %%
df.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-144c7b0decef> in <cell line: 0>()
# ----> 1 df.dtype()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values=missing values
# Out:
#   File "<ipython-input-19-5017bad096fb>", line 1
#     df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values=missing values
#                                                                                                                                                                                                  ^
# SyntaxError: invalid syntax

# %%
df= pd.read_csv(()'https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values=missing values)
# Out:
#   File "<ipython-input-20-f059d494f0de>", line 1
#     df= pd.read_csv(()'https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values=missing values)
#                                                                                                                                                                                                          ^
# SyntaxError: unmatched ')'

# %%
df= pd.read_csv(('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values=missing values)
# Out:
#   File "<ipython-input-21-8ee697b1cfe0>", line 1
#     df= pd.read_csv(('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values=missing values)
#                     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
df= pd.read_csv(('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values==missing values)
# Out:
#   File "<ipython-input-22-80f86a45da24>", line 1
#     df= pd.read_csv(('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv' ).na_values==missing values)
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
d

# %%
print (df2)
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034                             FDR          K-8
# 19478      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54234      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54235      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54236      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54238      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54239      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54240      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# ...

# %%
df2.head()
# Out:
#       School DBN                     School Name School Level  \
# 0         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2         01M034                             FDR          K-8
# 19478     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 0      Common Core Algebra  2017             4          s
# 1       Living Environment  2015            16       77.9
# 2       Living Environment  2016             9         74
# 19478  Common Core Algebra  2017             3          s
# 19479  Common Core Algebra  2017             1          s
#
#       Number Scoring Below 65 Percent Scoring Below 65  \
# 0                           s                        s
# 1                           1                      6.3
# 2                           1                     11.1
# ...

# %%
median=df2["Mean Score"].median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5bd4f264b274> in <cell line: 0>()
# ----> 1 median=df2["Mean Score"].median()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6557         **kwargs,
#    6558     ):
# -> 6559         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6560
#    6561     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
median=df2["Mean Score"].median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-5bd4f264b274> in <cell line: 0>()
# ----> 1 median=df2["Mean Score"].median()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6557         **kwargs,
#    6558     ):
# -> 6559         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6560
#    6561     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
median=df2["Mean Score"].median()
df[Mean Score]=.fillna(median, inplace=True)
# Out:
#   File "<ipython-input-28-5c1fdf2d8c8c>", line 2
#     df[Mean Score]=.fillna(median, inplace=True)
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
median=df2["Mean Score"].median()
df["Mean Score"]=.fillna(median, inplace=True)
# Out:
#   File "<ipython-input-29-4e0efd35d0e6>", line 2
#     df["Mean Score"]=.fillna(median, inplace=True)
#                      ^
# SyntaxError: invalid syntax

# %%
median=df2["Mean Score"].median()
df["Mean Score"].fillna(median, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-61b32cc605e7> in <cell line: 0>()
# ----> 1 median=df2["Mean Score"].median()
#       2 df["Mean Score"].fillna(median, inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6557         **kwargs,
#    6558     ):
# -> 6559         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6560
#    6561     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
missing_values= ["s"]

# %%
median=df2["Mean Score"].median()
df["Mean Score"]=.fillna(median, inplace=True)
# Out:
#   File "<ipython-input-32-4e0efd35d0e6>", line 2
#     df["Mean Score"]=.fillna(median, inplace=True)
#                      ^
# SyntaxError: invalid syntax

# %%
median=df2["Mean Score"].median()
df["Mean Score"].fillna(median, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-61b32cc605e7> in <cell line: 0>()
# ----> 1 median=df2["Mean Score"].median()
#       2 df["Mean Score"].fillna(median, inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6557         **kwargs,
#    6558     ):
# -> 6559         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6560
#    6561     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
dfFDR=df[df["School Name"]=="P.S. 034 Franklin D. Roosevelt"]

# %%
dfFDR.describe()
# Out:
#               Year  Total Tested
# count    29.000000     29.000000
# mean   2015.931034      5.000000
# std       0.842235      4.191829
# min    2015.000000      1.000000
# 25%    2015.000000      2.000000
# 50%    2016.000000      3.000000
# 75%    2017.000000      7.000000
# max    2017.000000     16.000000

# %%
dfFDR

# %%
dfFDR.max()
# Out:
# School DBN                                             01M034
# School Name                    P.S. 034 Franklin D. Roosevelt
# School Level                                              K-8
# Regents Exam                               Living Environment
# Year                                                     2017
# Total Tested                                               16
# Mean Score                                                  s
# Number Scoring Below 65                                     s
# Percent Scoring Below 65                                    s
# Number Scoring 65 or Above                                  s
# Percent Scoring 65 or Above                                 s
# Number Scoring 80 or Above                                  s
# Percent Scoring 80 or Above                                 s
# Number Scoring CR                                          na
# Percent Scoring CR                                         na
# dtype: object

# %%
df.count()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64

# %%
dfFDR.count()
# Out:
# School DBN                     29
# School Name                    29
# School Level                   29
# Regents Exam                   29
# Year                           29
# Total Tested                   29
# Mean Score                     29
# Number Scoring Below 65        29
# Percent Scoring Below 65       29
# Number Scoring 65 or Above     29
# Percent Scoring 65 or Above    29
# Number Scoring 80 or Above     29
# Percent Scoring 80 or Above    29
# Number Scoring CR              29
# Percent Scoring CR             29
# dtype: int64

# %%
dfFDR.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-20227ba200dc> in <cell line: 0>()
# ----> 1 dfFDR.median()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
dfFDR['Mean Score'].median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-387c60e44b57> in <cell line: 0>()
# ----> 1 dfFDR['Mean Score'].median()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6557         **kwargs,
#    6558     ):
# -> 6559         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6560
#    6561     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
dfFDR['Mean Score'] = pd.to_numeric(dfFDR['Mean Score'], errors='coerce')
# Out:
# <ipython-input-14-3f7337a37652>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFDR['Mean Score'] = pd.to_numeric(dfFDR['Mean Score'], errors='coerce')

# %%
dfFDR.hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Total Tested'}>],
#        [<Axes: title={'center': 'Mean Score'}>, <Axes: >]], dtype=object)

# %%
dfFDR.describe()
# Out:
#               Year  Total Tested  Mean Score
# count    29.000000     29.000000   10.000000
# mean   2015.931034      5.000000   76.750000
# std       0.842235      4.191829    2.298429
# min    2015.000000      1.000000   73.500000
# 25%    2015.000000      2.000000   74.375000
# 50%    2016.000000      3.000000   77.900000
# 75%    2017.000000      7.000000   77.975000
# max    2017.000000     16.000000   80.000000

# %%
dfFDR['mean score'].median()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-c80ae96d47fb> in <cell line: 0>()
# ----> 1 dfFDR['mean score'].median()
#
# ...

# %%
dfFDR['Mean Score'].median()
# Out:
# 77.9

# %%
dfFDR['Percent Scoring Below 65'] = pd.to_numeric(dfFDR['Percent Scoring Below 65'], errors='coerce')
# Out:
# <ipython-input-19-2025cbd8c70a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFDR['Percent Scoring Below 65'] = pd.to_numeric(dfFDR['Percent Scoring Below 65'], errors='coerce')

# %%
dfFDR = pd.to_numeric(dfFDR, errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0b4a07428d7a> in <cell line: 0>()
# ----> 1 dfFDR = pd.to_numeric(dfFDR, errors='coerce')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     204         values = np.array([arg], dtype="O")
#     205     elif getattr(arg, "ndim", 1) > 1:
# --> 206         raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     207     else:
#     208         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
dfFDR.describe()
# Out:
#               Year  Total Tested  Mean Score  Percent Scoring Below 65
# count    29.000000     29.000000   10.000000                 10.000000
# mean   2015.931034      5.000000   76.750000                  6.260000
# std       0.842235      4.191829    2.298429                  6.110319
# min    2015.000000      1.000000   73.500000                  0.000000
# 25%    2015.000000      2.000000   74.375000                  0.000000
# 50%    2016.000000      3.000000   77.900000                  6.300000
# 75%    2017.000000      7.000000   77.975000                 11.100000
# max    2017.000000     16.000000   80.000000                 16.700000

# %%
dfFDR.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0150860c88f4> in <cell line: 0>()
# ----> 1 dfFDR.describe()
#
# NameError: name 'dfFDR' is not defined

# %%
import pandas as pd

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
dfFDR=df[df["School Name"]=="P.S. 034 Franklin D. Roosevelt"]

# %%
dfFDR['Percent Scoring Below 65'] = pd.to_numeric(dfFDR['Percent Scoring Below 65'], errors='coerce')
# Out:
# <ipython-input-11-2025cbd8c70a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFDR['Percent Scoring Below 65'] = pd.to_numeric(dfFDR['Percent Scoring Below 65'], errors='coerce')

# %%
dfFDR.describe()
# Out:
#               Year  Total Tested  Percent Scoring Below 65
# count    29.000000     29.000000                 10.000000
# mean   2015.931034      5.000000                  6.260000
# std       0.842235      4.191829                  6.110319
# min    2015.000000      1.000000                  0.000000
# 25%    2015.000000      2.000000                  0.000000
# 50%    2016.000000      3.000000                  6.300000
# 75%    2017.000000      7.000000                 11.100000
# max    2017.000000     16.000000                 16.700000

# %%
dfFDR.hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Total Tested'}>],
#        [<Axes: title={'center': 'Number Scoring Below 65'}>,
#         <Axes: title={'center': 'Percent Scoring Below 65'}>],
#        [<Axes: title={'center': 'Percent Scoring 80 or Above'}>,
#         <Axes: >]], dtype=object)

# %%
dfFDR.head()
# Out:
#       School DBN                     School Name School Level  \
# 0         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 0      Common Core Algebra  2017             4          s
# 1       Living Environment  2015            16       77.9
# 2       Living Environment  2016             9         74
# 19478  Common Core Algebra  2017             3          s
# 19479  Common Core Algebra  2017             1          s
#
#        Number Scoring Below 65  Percent Scoring Below 65  \
# 0                          NaN                       NaN
# 1                          1.0                       6.3
# 2                          1.0                      11.1
# ...

# %%
dfFDR.tail()
# Out:
#        School DBN                     School Name School Level  \
# 139888     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139889     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139890     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139891     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139892     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 139888  Living Environment  2015             6       75.5
# 139889  Living Environment  2015             1          s
# 139890  Living Environment  2016             1          s
# 139891  Living Environment  2016             2          s
# 139892  Living Environment  2016             6       73.5
#
#        Number Scoring Below 65  Percent Scoring Below 65  \
# 139888                       1                      16.7
# 139889                       s                       NaN
# 139890                       s                       NaN
# ...

# %%
dfFDR['Number Scoring Below 65'] = pd.to_numeric(dfFDR['Number Scoring Below 65'], errors='coerce')
# Out:
# <ipython-input-15-06f3431a9956>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFDR['Number Scoring Below 65'] = pd.to_numeric(dfFDR['Number Scoring Below 65'], errors='coerce')

# %%
dfFDR.describe()
# Out:
#               Year  Total Tested  Number Scoring Below 65  \
# count    29.000000     29.000000                10.000000
# mean   2015.931034      5.000000                 0.600000
# std       0.842235      4.191829                 0.516398
# min    2015.000000      1.000000                 0.000000
# 25%    2015.000000      2.000000                 0.000000
# 50%    2016.000000      3.000000                 1.000000
# 75%    2017.000000      7.000000                 1.000000
# max    2017.000000     16.000000                 1.000000
#
#        Percent Scoring Below 65
# count                 10.000000
# mean                   6.260000
# std                    6.110319
# min                    0.000000
# 25%                    0.000000
# 50%                    6.300000
# 75%                   11.100000
# max                   16.700000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
from matplotlib import pyplot as plt
_df_3['Percent Scoring Below 65'].plot(kind='hist', bins=20, title='Percent Scoring Below 65')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
dfFDR['Percent Scoring Below 65'].mean()
# Out:
# 6.26

# %%
dfFDR['Percent Scoring Below 65'].describe()
# Out:
# count    10.000000
# mean      6.260000
# std       6.110319
# min       0.000000
# 25%       0.000000
# 50%       6.300000
# 75%      11.100000
# max      16.700000
# Name: Percent Scoring Below 65, dtype: float64

# %%
dfFDR['Percent Scoring Below 65'].median()
# Out:
# 6.3

# %%
df['Percent Scoring Below 65'].median()
# Out:
# 40.2

# %%
df['Percent Scoring Below 65'] = pd.to_numeric(df['Percent Scoring Below 65'], errors='coerce')

# %%
df['Percent Scoring Below 65'].mean()
# Out:
# 41.9336316361435

# %%
print (df['Percent Scoring Below 65'].mean())
# Out:
# 41.9336316361435

# %%
print (df['Percent Scoring Below 65'].mean(), dfFDR['Percent Scoring Below 65'].mean() )
# Out:
# 41.9336316361435 6.26

# %%
df['Percent Scoring 80 or Above'] = pd.to_numeric(df['Percent Scoring 80 or Above'], errors='coerce')

# %%
dfFDR['Percent Scoring 80 or Above'] = pd.to_numeric(dfFDR['Percent Scoring 80 or Above'], errors='coerce')
# Out:
# <ipython-input-32-2f8b302ff9c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFDR['Percent Scoring 80 or Above'] = pd.to_numeric(dfFDR['Percent Scoring 80 or Above'], errors='coerce')

# %%
print (df['Percent Scoring 80 or Above'].mean(), dfFDR['Percent Scoring 80 or Above'].mean() )
# Out:
# 22.692026781611705 38.6

# %%
dfFDR['Percent Scoring Below 65'].hist()
# Out:
# <Axes: >

# %%
dfFDR['Percent Scoring Below 65'], df['Percent Scoring Below 65'].hist()
# Out:
# (0          NaN
#  1          6.3
#  2         11.1
#  19478      NaN
#  19479      NaN
#  19480      6.3
#  19481     11.1
#  54234      NaN
#  54235      NaN
#  54236      NaN
#  54237      0.0
#  54238      NaN
#  54239      NaN
#  54240      NaN
#  102879     NaN
#  102880     NaN
#  102881     0.0
#  102882    11.1
#  102883     NaN
#  102884     NaN
#  139884     NaN
#  139885     NaN
#  139886     0.0
#  139887     NaN
#  139888    16.7
#  139889     NaN
#  139890     NaN
#  139891     NaN
#  139892     0.0
#  Name: Percent Scoring Below 65, dtype: float64,
#  <Axes: >)

# %%
dfFDR.plot(x='Year', y='Mean Score', kind='scatter')
# Out:
# <Axes: xlabel='Year', ylabel='Mean Score'>

# %%
dfFDR.plot(x='Year', y='Mean Score', kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-867434ade9ca> in <cell line: 0>()
# ----> 1 dfFDR.plot(x='Year', y='Mean Score', kind='bar')
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %%
dfFDR['Mean Score'] = pd.to_numeric(dfFDR['Mean Score'], errors='coerce')
# Out:
# <ipython-input-42-3f7337a37652>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFDR['Mean Score'] = pd.to_numeric(dfFDR['Mean Score'], errors='coerce')

# %%
dfFDR.plot(x='Year', y='Mean Score', kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
dfFDR.plot(x='Year', y='Percent Scoring Below 65', kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
#FDR seems to be overperforming other schools in general in terms of having a significantly lower amount of students who are failing these exams. Though it seems FDR stopped tracking failing students in 2017
